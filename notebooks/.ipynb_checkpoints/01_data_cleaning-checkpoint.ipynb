# %%
import pandas as pd

df = pd.read_excel(
    "../data/raw/Online Retail.xlsx",
    sheet_name="Online Retail",
    nrows=1000,
    engine="openpyxl"
)

print(df.shape)
# Out:
# (1000, 8)

# %%
df.shape
# Out:
# (1000, 8)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   InvoiceNo    1000 non-null   object
#  1   StockCode    1000 non-null   object
#  2   Description  999 non-null    str
#  3   Quantity     1000 non-null   int64
#  4   InvoiceDate  1000 non-null   datetime64[us]
#  5   UnitPrice    1000 non-null   float64
#  6   CustomerID   999 non-null    float64
#  7   Country      1000 non-null   str
# dtypes: datetime64[us](1), float64(2), int64(1), object(2), str(2)
# memory usage: 102.6+ KB

# %%
df.isnull().sum()
# Out:
# InvoiceNo      0
# StockCode      0
# Description    1
# Quantity       0
# InvoiceDate    0
# UnitPrice      0
# CustomerID     1
# Country        0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(23)

# %%
df.describe()
# Out:
#           Quantity                 InvoiceDate    UnitPrice    CustomerID
# count  1000.000000                        1000  1000.000000    999.000000
# mean     12.785000  2010-12-01 11:20:00.540000     3.037110  16023.130130
# min     -24.000000         2010-12-01 08:26:00     0.000000  12431.000000
# 25%       2.000000         2010-12-01 10:29:00     1.250000  14688.000000
# 50%       4.000000         2010-12-01 11:45:00     2.100000  16210.000000
# 75%      12.000000         2010-12-01 12:15:00     3.750000  17908.000000
# max     600.000000         2010-12-01 12:43:00   165.000000  18085.000000
# std      38.423706                         NaN     5.896942   1865.129933

# %%
df = df.drop_duplicates()
print(df.shape)
# Out:
# (977, 8)

# %%
df = df.dropna(subset=["CustomerID"])
print(df.shape)
# Out:
# (976, 8)

# %%
df.to_csv("../data/cleaned/cleaned_retail_day2.csv",index=False)

# %%
df.shape
# Out:
# (976, 8)

# %%
df.isnull().sum()
# Out:
# InvoiceNo      0
# StockCode      0
# Description    0
# Quantity       0
# InvoiceDate    0
# UnitPrice      0
# CustomerID     0
# Country        0
# dtype: int64
